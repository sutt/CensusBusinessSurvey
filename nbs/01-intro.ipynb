# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
books = pd.read_csv('../data/goodreads-10k/books.csv')

# %%
# convert float to int with na values
books['original_publication_year'] = books['original_publication_year'].fillna(0)
books['original_publication_year'] = books['original_publication_year'].astype(int)

# %%
books
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors  original_publication_year  \
# ...

# %%
books['new_col'] = books['original_publication_year'].map(lambda x: int(x) if pd.isna(x) else x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22820/3697190234.py in <module>
# ----> 1 books['new_col'] = books['original_publication_year'].map(lambda x: int(x) if pd.isna(x) else x)
#
# c:\Users\wsutt\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# c:\Users\wsutt\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# ...

# %%
books[books['original_publication_year'] == 1999]
# Out:
#         id  book_id  best_book_id  work_id  books_count        isbn  \
# 17      18        5             5  2402163          376  043965548X
# 67      68    22628         22628  2236198          128   671027344
# 106    107     3473          3473  3143497          131   446693804
# 147    148     2865          2865  3358875          169   452287022
# 233    234   439288        439288   118521           87  014131088X
# ...    ...      ...           ...      ...          ...         ...
# 9904  9905      449           449  1344597           45   312263996
# 9905  9906  1087207       1087207  2902197           16  1421501929
# 9965  9966     9864          9864  3279710           72   312254997
# 9971  9972     4984          4984  6558445           28    99282968
# 9972  9973   849380        849380     4370           52   609805797
#
#             isbn13                                  authors  \
# 17    9.780440e+12  J.K. Rowling, Mary GrandPré, Rufus Beck
# ...

# %%
books[books['publication_year']== 1999]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\wsutt\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\wsutt\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\wsutt\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'publication_year'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
books.head(5)
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# ...

# %%
top_authors = books.groupby('authors').agg('count')[['book_id']].sort_values('book_id', ascending=False)
top_authors.head(10)
# Out:
#                  book_id
# authors
# Stephen King          60
# Nora Roberts          59
# Dean Koontz           47
# Terry Pratchett       42
# Agatha Christie       39
# Meg Cabot             37
# James Patterson       36
# David Baldacci        34
# John Grisham          33
# J.D. Robb             33

# %%
plt.hist(top_authors['book_id']);

# make plot non transparent
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['figure.edgecolor'] = 'white'


# ax = plt.gca()
# ax.xaxis.label.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='none'))
# ax.yaxis.label.set_bbox(dict(facecolor='white', alpha=1.0, edgecolor='none'))

# ax.xaxis.
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some data
data = np.random.randn(1000)

# Create a histogram
plt.hist(data, bins=30, edgecolor='black')

# Set axes labels
plt.xlabel('Value')
plt.ylabel('Frequency')

# Get the current axes
ax = plt.gca()

# Set axes label background color and alpha (transparency)
ax.xaxis.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='none'))
ax.yaxis.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='none'))

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22820/2702950191.py in <module>
#      16
#      17 # Set axes label background color and alpha (transparency)
# ---> 18 ax.xaxis.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='none'))
#      19 ax.yaxis.set_bbox(dict(facecolor='white', alpha=0.5, edgecolor='none'))
#      20
#
# AttributeError: 'XAxis' object has no attribute 'set_bbox'
